# %% [markdown]
# <a href="https://colab.research.google.com/github/GauriRB/DMW_Practical/blob/main/dmw1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Data Cleaning**

# %%
 #importing libraries
 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os

# %%
 #listing files in current directory
 
print(os.listdir())
# Out:
# ['.config', 'data2.csv', 'data1.csv', 'sample_data']

# %%
#reading csv file

df = pd.read_csv('data1.csv')

# %%
#displaying csv file

df
# Out:
#     Student_id  Age  Gender      Grade Employed
# 0            1   19    Male  1st Class      yes
# 1            2   20  Female  2nd Class       no
# 2            3   18    Male  1st Class       no
# 3            4   21  Female  2nd Class       no
# 4            5   19    Male  1st Class      NaN
# 5            6   20    Male  2nd Class      yes
# 6            7   19  Female        NaN      yes
# 7            8   21    Male  3rd Class      yes
# 8            9   22  Female  3rd Class      yes
# 9           10   21    Male  1st Class      NaN
# 10          11   20  Female        NaN      yes
# 11          12   20    Male  1st Class       no
# 12          13   19    Male  1st Class      yes
# 13          14   20  Female        NaN       no
# 14          15   19    Male  1st Class      yes

# %%
#To view some basic statistical details like percentile, mean, std etc. of a data frame

df.describe()
# Out:
#        Student_id        Age
# count   15.000000  15.000000
# mean     8.000000  19.866667
# std      4.472136   1.060099
# min      1.000000  18.000000
# 25%      4.500000  19.000000
# 50%      8.000000  20.000000
# 75%     11.500000  20.500000
# max     15.000000  22.000000

# %%
#To print name of all columns in our data set

print(df.columns)
# Out:
# Index(['Student_id', 'Age', 'Gender', 'Grade', 'Employed'], dtype='object')

# %%
 #number of rows and columns in csv file

 df.shape
# Out:
# (15, 5)

# %%
#To print data types of each column

df.dtypes
# Out:
# Student_id     int64
# Age            int64
# Gender        object
# Grade         object
# Employed      object
# dtype: object

# %%
#To display information

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Student_id  15 non-null     int64
#  1   Age         15 non-null     int64
#  2   Gender      15 non-null     object
#  3   Grade       12 non-null     object
#  4   Employed    13 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 728.0+ bytes

# %%
#number of null values in each column

df.isnull().sum()
# Out:
# Student_id    0
# Age           0
# Gender        0
# Grade         3
# Employed      2
# dtype: int64

# %%
#to chaeck null values

df.isnull()
# Out:
#     Student_id    Age  Gender  Grade  Employed
# 0        False  False   False  False     False
# 1        False  False   False  False     False
# 2        False  False   False  False     False
# 3        False  False   False  False     False
# 4        False  False   False  False      True
# 5        False  False   False  False     False
# 6        False  False   False   True     False
# 7        False  False   False  False     False
# 8        False  False   False  False     False
# 9        False  False   False  False      True
# 10       False  False   False   True     False
# 11       False  False   False  False     False
# 12       False  False   False  False     False
# 13       False  False   False   True     False
# 14       False  False   False  False     False

# %%
df['Age']
# Out:
# 0     19
# 1     20
# 2     18
# 3     21
# 4     19
# 5     20
# 6     19
# 7     21
# 8     22
# 9     21
# 10    20
# 11    20
# 12    19
# 13    20
# 14    19
# Name: Age, dtype: int64

# %%
 #To check NaN/missing values in df

df.isna()
# Out:
#     Student_id    Age  Gender  Grade  Employed
# 0        False  False   False  False     False
# 1        False  False   False  False     False
# 2        False  False   False  False     False
# 3        False  False   False  False     False
# 4        False  False   False  False      True
# 5        False  False   False  False     False
# 6        False  False   False   True     False
# 7        False  False   False  False     False
# 8        False  False   False  False     False
# 9        False  False   False  False      True
# 10       False  False   False   True     False
# 11       False  False   False  False     False
# 12       False  False   False  False     False
# 13       False  False   False   True     False
# 14       False  False   False  False     False

# %% [markdown]
# Replacing Null Values

# %%
# Fill missing value of integer column with mode
df['Employed'] = df['Employed'].fillna(df['Employed'].mode()[0])

# %%
# Fill missing value of integer column with mode
df['Grade'] = df['Grade'].fillna(df['Grade'].mode()[0])

# %%
 #Displaying csv file after replacing null values
 
df
# Out:
#     Student_id  Age  Gender      Grade Employed
# 0            1   19    Male  1st Class      yes
# 1            2   20  Female  2nd Class       no
# 2            3   18    Male  1st Class       no
# 3            4   21  Female  2nd Class       no
# 4            5   19    Male  1st Class      yes
# 5            6   20    Male  2nd Class      yes
# 6            7   19  Female  1st Class      yes
# 7            8   21    Male  3rd Class      yes
# 8            9   22  Female  3rd Class      yes
# 9           10   21    Male  1st Class      yes
# 10          11   20  Female  1st Class      yes
# 11          12   20    Male  1st Class       no
# 12          13   19    Male  1st Class      yes
# 13          14   20  Female  1st Class       no
# 14          15   19    Male  1st Class      yes

# %%
df.head(10) #Display first 10 rows of dataset
# Out:
#    Student_id  Age  Gender      Grade Employed
# 0           1   19    Male  1st Class      yes
# 1           2   20  Female  2nd Class       no
# 2           3   18    Male  1st Class       no
# 3           4   21  Female  2nd Class       no
# 4           5   19    Male  1st Class      yes
# 5           6   20    Male  2nd Class      yes
# 6           7   19  Female  1st Class      yes
# 7           8   21    Male  3rd Class      yes
# 8           9   22  Female  3rd Class      yes
# 9          10   21    Male  1st Class      yes

# %% [markdown]
# Data Integration

# %%
 #Reading data2.csv file

df1 = pd.read_csv('data2.csv')

# %%
df1
# Out:
#     Student_id  Mark     City
# 0            1    95  Chennai
# 1            2    70    Delhi
# 2            3    98   Mumbai
# 3            4    75     Pune
# 4            5    89    Kochi
# 5            6    69  Gwalior
# 6            7    52   Bhopal
# 7            8    54  Chennai
# 8            9    55    Delhi
# 9           10    94   Mumbai
# 10          11    52     Pune
# 11          12    90    Kochi
# 12          13    92  Gwalior
# 13          14    55   Bhopal
# 14          15    97     Pune

# %%
df1.isna() #To check NaN values in df1
# Out:
#     Student_id   Mark   City
# 0        False  False  False
# 1        False  False  False
# 2        False  False  False
# 3        False  False  False
# 4        False  False  False
# 5        False  False  False
# 6        False  False  False
# 7        False  False  False
# 8        False  False  False
# 9        False  False  False
# 10       False  False  False
# 11       False  False  False
# 12       False  False  False
# 13       False  False  False
# 14       False  False  False

# %%
#To integrate/merge two datasets in df2

df2 = pd.concat([df, df1])

# %%
#display Mereged dataset df2

df2
# Out:
#     Student_id   Age  Gender      Grade Employed  Mark     City
# 0            1  19.0    Male  1st Class      yes   NaN      NaN
# 1            2  20.0  Female  2nd Class       no   NaN      NaN
# 2            3  18.0    Male  1st Class       no   NaN      NaN
# 3            4  21.0  Female  2nd Class       no   NaN      NaN
# 4            5  19.0    Male  1st Class      yes   NaN      NaN
# 5            6  20.0    Male  2nd Class      yes   NaN      NaN
# 6            7  19.0  Female  1st Class      yes   NaN      NaN
# 7            8  21.0    Male  3rd Class      yes   NaN      NaN
# 8            9  22.0  Female  3rd Class      yes   NaN      NaN
# 9           10  21.0    Male  1st Class      yes   NaN      NaN
# 10          11  20.0  Female  1st Class      yes   NaN      NaN
# 11          12  20.0    Male  1st Class       no   NaN      NaN
# 12          13  19.0    Male  1st Class      yes   NaN      NaN
# 13          14  20.0  Female  1st Class       no   NaN      NaN
# ...

# %% [markdown]
# **Data Transformation**

# %%
#Displaying histogram of df dataset

df.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fa8882d7710>,
# ...
#       dtype=object)

# %%
a = np.array(df['Age'])

# %%
#Plotting pie chart of Age column of the dataset

plt.pie(a)
# Out:
# ([<matplotlib.patches.Wedge at 0x7fa887cbd250>,
# ...
#  [Text(1.0780069950701894, 0.2188627848213146, ''),
#   Text(0.900697575560008, 0.6314616990604609, ''),
#   Text(0.5831297337675992, 0.9327163092795842, ''),
#   Text(0.1617620103007704, 1.088040923873479, ''),
#   Text(-0.29774728050115823, 1.0589365216830349, ''),
#   Text(-0.6961504240008856, 0.8516892550475129, ''),
#   Text(-0.9785228427048346, 0.5024868618231226, ''),
#   Text(-1.098472186311045, 0.05795563735335149, ''),
#   Text(-1.012907450886677, -0.42897377068796866, ''),
#   Text(-0.7227340941361589, -0.8292499196099966, ''),
#   Text(-0.3088942561488285, -1.0557387643343699, ''),
#   Text(0.15028267501451212, -1.0896857884686222, ''),
#   Text(0.5732644461500945, -0.9388119485712917, ''),
#   Text(0.9006974868774325, -0.6314618255545441, ''),
#   Text(1.0780069643330594, -0.21886293621676123, '')])

# %%
#printing no. of unique values which are present in Age column

df['Age'].nunique()
# Out:
# 5

# %% [markdown]
#  **Data Reduction**

# %%
df #diplay dataset
# Out:
#     Student_id  Age  Gender      Grade Employed
# 0            1   19    Male  1st Class      yes
# 1            2   20  Female  2nd Class       no
# 2            3   18    Male  1st Class       no
# 3            4   21  Female  2nd Class       no
# 4            5   19    Male  1st Class      yes
# 5            6   20    Male  2nd Class      yes
# 6            7   19  Female  1st Class      yes
# 7            8   21    Male  3rd Class      yes
# 8            9   22  Female  3rd Class      yes
# 9           10   21    Male  1st Class      yes
# 10          11   20  Female  1st Class      yes
# 11          12   20    Male  1st Class       no
# 12          13   19    Male  1st Class      yes
# 13          14   20  Female  1st Class       no
# 14          15   19    Male  1st Class      yes

# %%
#Reducing unnecessary column(s)

df3=df.drop(['Employed'], axis=1)

# %%
df3
# Out:
#     Student_id  Age  Gender      Grade
# 0            1   19    Male  1st Class
# 1            2   20  Female  2nd Class
# 2            3   18    Male  1st Class
# 3            4   21  Female  2nd Class
# 4            5   19    Male  1st Class
# 5            6   20    Male  2nd Class
# 6            7   19  Female  1st Class
# 7            8   21    Male  3rd Class
# 8            9   22  Female  3rd Class
# 9           10   21    Male  1st Class
# 10          11   20  Female  1st Class
# 11          12   20    Male  1st Class
# 12          13   19    Male  1st Class
# 13          14   20  Female  1st Class
# 14          15   19    Male  1st Class

# %%
df
# Out:
#     Student_id  Age  Gender      Grade Employed
# 0            1   19    Male  1st Class      yes
# 1            2   20  Female  2nd Class       no
# 2            3   18    Male  1st Class       no
# 3            4   21  Female  2nd Class       no
# 4            5   19    Male  1st Class      yes
# 5            6   20    Male  2nd Class      yes
# 6            7   19  Female  1st Class      yes
# 7            8   21    Male  3rd Class      yes
# 8            9   22  Female  3rd Class      yes
# 9           10   21    Male  1st Class      yes
# 10          11   20  Female  1st Class      yes
# 11          12   20    Male  1st Class       no
# 12          13   19    Male  1st Class      yes
# 13          14   20  Female  1st Class       no
# 14          15   19    Male  1st Class      yes
